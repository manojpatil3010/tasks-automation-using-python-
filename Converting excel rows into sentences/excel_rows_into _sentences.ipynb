# %%
import pandas as pd

df= pd.read_excel("rows_to_sent.xlsx")
df.head()
# Out:
#              a               b             c            d  Unnamed: 4  \
# 0  caterpillar  (kcc_question)     acid lime  (crop_type)         NaN
# 1  caterpillar  (kcc_question)   bengal gram  (crop_type)         NaN
# 2  caterpillar  (kcc_question)  bitter groud  (crop_type)         NaN
# 3  caterpillar  (kcc_question)       brinjal  (crop_type)         NaN
# 4  caterpillar  (kcc_question)      capsicum  (crop_type)         NaN
#
#            e          f
# 0     Mumbai     mumbai
# 1      Delhi      delhi
# 2  Bangalore  bangalore
# 3  Hyderabad  hyderabad
# 4  Ahmedabad  ahmedabad

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'Unnamed: 4', 'e', 'f'], dtype='object')

# %%
df["a"]
# Out:
# 0      caterpillar
# 1      caterpillar
# 2      caterpillar
# 3      caterpillar
# 4      caterpillar
#           ...
# 136      mealy bug
# 137            rot
# 138            rot
# 139            rot
# 140            rot
# Name: a, Length: 141, dtype: object

# %%
a = list(df['a'])
b = list(df['b'])
c = list(df['c'])
d = list(df['d'])

for a,b,c,d in zip(a,b,c,d):
    print("-[{0}]{1} [{2}]{3}".format(a,b,c,d))

    
#     print("-[{0}]{1}".format(a,b))
# Out:
# -[caterpillar](kcc_question) [acid lime](crop_type)
# -[caterpillar](kcc_question) [bengal gram](crop_type)
# -[caterpillar](kcc_question) [bitter groud](crop_type)
# -[caterpillar](kcc_question) [brinjal](crop_type)
# -[caterpillar](kcc_question) [capsicum](crop_type)
# -[caterpillar](kcc_question) [cotton](crop_type)
# -[caterpillar](kcc_question) [cauliflower](crop_type)
# -[caterpillar](kcc_question) [chillies](crop_type)
# -[caterpillar](kcc_question) [soybean](crop_type)
# -[caterpillar](kcc_question) [marigold](crop_type)
# -[caterpillar](kcc_question) [maize](crop_type)
# -[caterpillar](kcc_question) [green gram](crop_type)
# -[caterpillar](kcc_question) [onion](crop_type)
# -[caterpillar](kcc_question) [paddy](crop_type)
# -[caterpillar](kcc_question) [pigeonpea](crop_type)
# -[caterpillar](kcc_question) [rose](crop_type)
# -[caterpillar](kcc_question) [sorghum](crop_type)
# -[fungal](kcc_question) [bengal gram](crop_type)
# -[fungal](kcc_question) [brinjal](crop_type)
# ...

# %%
c = list(df['c'])
d = list(df['d'])

que=[]
for c,d in zip(c,d):
    que.append("-[{0}]{1}".format(c,d))
for i in set(que):
    print(i)
# Out:
# -[drum stick](crop_type)
# -[cucumber](crop_type)
# -[fenugreek](crop_type)
# -[bitter groud](crop_type)
# -[brinjal](crop_type)
# -[maize](crop_type)
# -[bitter gourd](crop_type)
# -[pigeon pea](crop_type)
# -[bottle gourd](crop_type)
# -[bhindi](crop_type)
# -[mango](crop_type)
# -[marigold](crop_type)
# -[sorghum](crop_type)
# -[sponge gourd](crop_type)
# -[pigeonpea](crop_type)
# -[wheat](crop_type)
# -[onion](crop_type)
# -[chillies](crop_type)
# -[papaya](crop_type)
# -[ridge groud](crop_type)
# -[green gram](crop_type)
# -[cotton](crop_type)
# -[mamgo](crop_type)
# -[pigeon peas](crop_type)
# -[french bean](crop_type)
# -[mothbean](crop_type)
# -[sponge groud](crop_type)
# -[sugarcanre](crop_type)
# -[cowpea](crop_type)
# -[paddy](crop_type)
# -[tomato](crop_type)
# -[groundnut](crop_type)
# -[rose](crop_type)
# -[black gram](crop_type)
# -[acid lime](crop_type)
# -[bengal gram](crop_type)
# -[ridge gourd](crop_type)
# -[capsicum](crop_type)
# -[soybean](crop_type)
# ...

# %%
for i in list(df["f"]):
    print(f"-weather today [{i}](location)")
# Out:
# -weather today [mumbai](location)
# -weather today [delhi](location)
# -weather today [bangalore](location)
# -weather today [hyderabad](location)
# -weather today [ahmedabad](location)
# -weather today [chennai](location)
# -weather today [kolkata](location)
# -weather today [surat](location)
# -weather today [pune](location)
# -weather today [jaipur](location)
# -weather today [lucknow](location)
# -weather today [kanpur](location)
# -weather today [nagpur](location)
# -weather today [indore](location)
# -weather today [thane](location)
# -weather today [bhopal](location)
# -weather today [visakhapatnam](location)
# -weather today [pimpri and chinchwad](location)
# -weather today [patna](location)
# -weather today [vadodara](location)
# -weather today [ghaziabad](location)
# -weather today [ludhiana](location)
# -weather today [agra](location)
# -weather today [nashik](location)
# -weather today [faridabad](location)
# -weather today [meerut](location)
# ...
